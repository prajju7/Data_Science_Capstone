# %% [markdown]
# # CLUSTERING

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import json
import csv
import requests

# %%
client_id ='Q0I22GOSO21HDHF11UPP3I4VOJ0MCI101OX0VFWOJNSZRWUO'
client_secret = 'ZBDPPRIYDKXR0XHEHEKJOYVC32RIFCFV0PLPOU4FORGKPEQ0'
v = '20200503'
venue = 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(client_id,client_secret,v)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Q0I22GOSO21HDHF11UPP3I4VOJ0MCI101OX0VFWOJNSZRWUO&client_secret=ZBDPPRIYDKXR0XHEHEKJOYVC32RIFCFV0PLPOU4FORGKPEQ0&v=20200503'

# %% [markdown]
# ### As it is taking very long time for feteching coordinates therefore we use csv file

# %%
df_co = pd.read_csv(r'C:\Users\My Pc\Downloads\Geospatial_Coordinates.csv')

# %%
df = pd.read_csv(r'C:\Python\Scripts\Capstone\toronto_postal.csv')

# %%
a = df.sort_values(['Postal Code']).reset_index()[["Postal Code","Borough","Neighbourhood"]]
a["Latitude"] = df_co["Latitude"]
a["Longitude"] = df_co["Longitude"]
a
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                      Malvern , Rouge  43.806686 -79.194353
# 1             Rouge Hill , Port Union , Highland Creek  43.784535 -79.160497
# 2                  Guildwood , Morningside , West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village , St. Phillips , Martin Grov...  43.688905 -79.554724
# 101  South Steeles , Silverstone , Humbergate , Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
a.loc[a["Borough"]== "York"]
# Out:
#    Postal Code Borough                                      Neighbourhood  \
# 73         M6C    York                                 Humewood-Cedarvale
# 74         M6E    York                                Caledonia-Fairbanks
# 80         M6M    York  Del Ray , Mount Dennis , Keelsdale and Silvert...
# 81         M6N    York                     Runnymede , The Junction North
# 98         M9N    York                                             Weston
#
#      Latitude  Longitude
# 73  43.693781 -79.428191
# 74  43.689026 -79.453512
# 80  43.691116 -79.476013
# 81  43.673185 -79.487262
# 98  43.706876 -79.518188

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(a['Borough'].unique()),
        a.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %%
a['Borough'].unique()
# Out:
# array(['Scarborough', 'North York', 'East York', 'East Toronto',
#        'Central Toronto', 'Downtown Toronto', 'York', 'West Toronto',
#        'Mississauga', 'Etobicoke'], dtype=object)

# %%
a=a[a['Borough'].str.contains("Toronto")]
toronto_data = a.head()
toronto_data
# Out:
#    Postal Code          Borough                    Neighbourhood   Latitude  \
# 37         M4E     East Toronto                      The Beaches  43.676357
# 41         M4K     East Toronto    The Danforth West , Riverdale  43.679557
# 42         M4L     East Toronto  India Bazaar , The Beaches West  43.668999
# 43         M4M     East Toronto                  Studio District  43.659526
# 44         M4N  Central Toronto                    Lawrence Park  43.728020
#
#     Longitude
# 37 -79.293031
# 41 -79.352188
# 42 -79.315572
# 43 -79.340923
# 44 -79.388790

# %%
address = 'Toronto'
latitude = None
geolocator = Nominatim(user_agent="ny_explorer")
while (latitude is None):
    try :
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
    except Exception as e:
        latitude =None
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
import folium
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(a['Latitude'], a['Longitude'], a['Borough'], a['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitude
# Out:
# 40.7149555

# %%
longitude
# Out:
# -74.0153365

# %%
CLIENT_ID ='Q0I22GOSO21HDHF11UPP3I4VOJ0MCI101OX0VFWOJNSZRWUO'
CLIENT_SECRET  = 'ZBDPPRIYDKXR0XHEHEKJOYVC32RIFCFV0PLPOU4FORGKPEQ0'
VERSION  = '20200503'

# %%
def getNearbyVenues(names, latitudes, longitudes):
    radius=500
    LIMIT=100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighbourhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West , Riverdale
# India Bazaar , The Beaches West
# Studio District
# Lawrence Park

# %%
toronto_venues
# Out:
#                       Neighborhood  Neighborhood Latitude  \
# 0                      The Beaches              43.676357
# 1                      The Beaches              43.676357
# 2                      The Beaches              43.676357
# 3                      The Beaches              43.676357
# 4    The Danforth West , Riverdale              43.679557
# ..                             ...                    ...
# 107                Studio District              43.659526
# 108                  Lawrence Park              43.728020
# 109                  Lawrence Park              43.728020
# 110                  Lawrence Park              43.728020
# 111                  Lawrence Park              43.728020
#
#      Neighborhood Longitude                               Venue  \
# 0                -79.293031                   Glen Manor Ravine
# 1                -79.293031  The Big Carrot Natural Food Market
# 2                -79.293031                 Grover Pub and Grub
# 3                -79.293031                       Upper Beaches
# 4                -79.352188                       MenEssentials
# ..                      ...                                 ...
# 107              -79.340923                         Pizza Thick
# 108              -79.388790                Lawrence Park Ravine
# 109              -79.388790                        Averax Group
# 110              -79.388790                  Zodiac Swim School
# 111              -79.388790      TTC Bus #162 - Lawrence-Donway
#
#      Venue Latitude  Venue Longitude              Venue Category
# 0         43.676821       -79.293942                       Trail
# 1         43.678879       -79.297734           Health Food Store
# 2         43.679181       -79.297215                         Pub
# 3         43.680563       -79.292869                Neighborhood
# 4         43.677820       -79.351265              Cosmetics Shop
# ..              ...              ...                         ...
# 107       43.661464       -79.338656                 Pizza Place
# 108       43.726963       -79.394382                        Park
# 109       43.727406       -79.383103  Construction & Landscaping
# 110       43.728532       -79.382860                 Swim School
# 111       43.728026       -79.382805                    Bus Line
#
# [112 rows x 7 columns]

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                  Neighborhood Latitude  \
# Neighborhood
# India Bazaar , The Beaches West                     20
# Lawrence Park                                        4
# Studio District                                     41
# The Beaches                                          4
# The Danforth West , Riverdale                       43
#
#                                  Neighborhood Longitude  Venue  \
# Neighborhood
# India Bazaar , The Beaches West                      20     20
# Lawrence Park                                         4      4
# Studio District                                      41     41
# The Beaches                                           4      4
# The Danforth West , Riverdale                        43     43
#
#                                  Venue Latitude  Venue Longitude  \
# Neighborhood
# India Bazaar , The Beaches West              20               20
# Lawrence Park                                 4                4
# Studio District                              41               41
# The Beaches                                   4                4
# The Danforth West , Riverdale                43               43
#
#                                  Venue Category
# Neighborhood
# India Bazaar , The Beaches West              20
# Lawrence Park                                 4
# Studio District                              41
# The Beaches                                   4
# The Danforth West , Riverdale                43

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot.drop(['Neighborhood'],axis=1,inplace=True) 
toronto_onehot.insert(loc=0, column='Neighborhood', value=toronto_venues['Neighborhood'] )
toronto_onehot.shape
# Out:
# (112, 62)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                       Neighborhood  American Restaurant    Bakery     Bank  \
# 0  India Bazaar , The Beaches West             0.000000  0.000000  0.00000
# 1                    Lawrence Park             0.000000  0.000000  0.00000
# 2                  Studio District             0.048780  0.048780  0.02439
# 3                      The Beaches             0.000000  0.000000  0.00000
# 4    The Danforth West , Riverdale             0.023256  0.023256  0.00000
#
#        Bar  Bookstore   Brewery  Bubble Tea Shop  Burrito Place  Bus Line  \
# 0  0.00000   0.000000  0.050000         0.000000           0.05      0.00
# 1  0.00000   0.000000  0.000000         0.000000           0.00      0.25
# 2  0.02439   0.024390  0.048780         0.000000           0.00      0.00
# 3  0.00000   0.000000  0.000000         0.000000           0.00      0.00
# 4  0.00000   0.046512  0.023256         0.023256           0.00      0.00
#
#    ...  Seafood Restaurant       Spa  Stationery Store  Steakhouse  \
# 0  ...             0.00000  0.000000           0.00000        0.05
# 1  ...             0.00000  0.000000           0.00000        0.00
# 2  ...             0.02439  0.000000           0.02439        0.00
# 3  ...             0.00000  0.000000           0.00000        0.00
# 4  ...             0.00000  0.023256           0.00000        0.00
#
#    Sushi Restaurant  Swim School  Thai Restaurant     Trail  Wine Bar  \
# 0              0.05         0.00          0.00000  0.000000   0.00000
# 1              0.00         0.25          0.00000  0.000000   0.00000
# 2              0.00         0.00          0.02439  0.000000   0.02439
# 3              0.00         0.00          0.00000  0.250000   0.00000
# 4              0.00         0.00          0.00000  0.023256   0.00000
#
#    Yoga Studio
# 0     0.000000
# 1     0.000000
# 2     0.024390
# 3     0.000000
# 4     0.023256
#
# [5 rows x 62 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                       Neighborhood 1st Most Common Venue  \
# 0  India Bazaar , The Beaches West  Fast Food Restaurant
# 1                    Lawrence Park                  Park
# 2                  Studio District                  Café
# 3                      The Beaches                 Trail
# 4    The Danforth West , Riverdale      Greek Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0        Sandwich Place     Food & Drink Shop                         Pub
# 1           Swim School              Bus Line  Construction & Landscaping
# 2           Coffee Shop               Brewery                   Gastropub
# 3                   Pub     Health Food Store                 Yoga Studio
# 4           Coffee Shop    Italian Restaurant          Frozen Yogurt Shop
#
#      5th Most Common Venue    6th Most Common Venue   7th Most Common Venue  \
# 0       Italian Restaurant                      Gym            Liquor Store
# 1  Comfort Food Restaurant  Fruit & Vegetable Store      Frozen Yogurt Shop
# 2      American Restaurant                   Bakery               Bookstore
# 3                    Diner        Convenience Store          Cosmetics Shop
# 4                Bookstore           Ice Cream Shop  Furniture / Home Store
#
#   8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 0     Fish & Chips Shop         Burrito Place            Movie Theater
# 1     Food & Drink Shop           Fish Market        Fish & Chips Shop
# 2                   Bar                  Bank              Cheese Shop
# 3       Coworking Space          Dessert Shop        Fish & Chips Shop
# 4     Indian Restaurant         Grocery Store  Fruit & Vegetable Store

# %%
from sklearn.cluster import KMeans
import folium 
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 1, 4, 2, 0])

# %%
neighborhoods_venues_sorted.head()
# Out:
#                                 1st Most Common Venue 2nd Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West  Fast Food Restaurant        Sandwich Place
# Lawrence Park                                    Park           Swim School
# Studio District                                  Café           Coffee Shop
# The Beaches                                     Trail                   Pub
# The Danforth West , Riverdale        Greek Restaurant           Coffee Shop
#
#                                 3rd Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West     Food & Drink Shop
# Lawrence Park                                Bus Line
# Studio District                               Brewery
# The Beaches                         Health Food Store
# The Danforth West , Riverdale      Italian Restaurant
#
#                                       4th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West                         Pub
# Lawrence Park                    Construction & Landscaping
# Studio District                                   Gastropub
# The Beaches                                     Yoga Studio
# The Danforth West , Riverdale            Frozen Yogurt Shop
#
#                                    5th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West       Italian Restaurant
# Lawrence Park                    Comfort Food Restaurant
# Studio District                      American Restaurant
# The Beaches                                        Diner
# The Danforth West , Riverdale                  Bookstore
#
#                                    6th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West                      Gym
# Lawrence Park                    Fruit & Vegetable Store
# Studio District                                   Bakery
# The Beaches                            Convenience Store
# The Danforth West , Riverdale             Ice Cream Shop
#
#                                   7th Most Common Venue 8th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West            Liquor Store     Fish & Chips Shop
# Lawrence Park                        Frozen Yogurt Shop     Food & Drink Shop
# Studio District                               Bookstore                   Bar
# The Beaches                              Cosmetics Shop       Coworking Space
# The Danforth West , Riverdale    Furniture / Home Store     Indian Restaurant
#
#                                 9th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West         Burrito Place
# Lawrence Park                             Fish Market
# Studio District                                  Bank
# The Beaches                              Dessert Shop
# The Danforth West , Riverdale           Grocery Store
#
#                                   10th Most Common Venue Postal Code  \
# Neighborhood
# India Bazaar , The Beaches West            Movie Theater         M4L
# Lawrence Park                          Fish & Chips Shop         M4N
# Studio District                              Cheese Shop         M4M
# The Beaches                            Fish & Chips Shop         M4E
# The Danforth West , Riverdale    Fruit & Vegetable Store         M4K
#
#                                          Borough   Latitude  Longitude
# Neighborhood
# India Bazaar , The Beaches West     East Toronto  43.668999 -79.315572
# Lawrence Park                    Central Toronto  43.728020 -79.388790
# Studio District                     East Toronto  43.659526 -79.340923
# The Beaches                         East Toronto  43.676357 -79.293031
# The Danforth West , Riverdale       East Toronto  43.679557 -79.352188

# %%
#neighborhoods_venues_sorted = neighborhoods_venues_sorted.set_index("Neighborhood").join(toronto_data.set_index("Neighbourhood"))
#neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted.head()
# Out:
#                                  Cluster Labels 1st Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West               3  Fast Food Restaurant
# Lawrence Park                                 1                  Park
# Studio District                               4                  Café
# The Beaches                                   2                 Trail
# The Danforth West , Riverdale                 0      Greek Restaurant
#
#                                 2nd Most Common Venue 3rd Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West        Sandwich Place     Food & Drink Shop
# Lawrence Park                             Swim School              Bus Line
# Studio District                           Coffee Shop               Brewery
# The Beaches                                       Pub     Health Food Store
# The Danforth West , Riverdale             Coffee Shop    Italian Restaurant
#
#                                       4th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West                         Pub
# Lawrence Park                    Construction & Landscaping
# Studio District                                   Gastropub
# The Beaches                                     Yoga Studio
# The Danforth West , Riverdale            Frozen Yogurt Shop
#
#                                    5th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West       Italian Restaurant
# Lawrence Park                    Comfort Food Restaurant
# Studio District                      American Restaurant
# The Beaches                                        Diner
# The Danforth West , Riverdale                  Bookstore
#
#                                    6th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West                      Gym
# Lawrence Park                    Fruit & Vegetable Store
# Studio District                                   Bakery
# The Beaches                            Convenience Store
# The Danforth West , Riverdale             Ice Cream Shop
#
#                                   7th Most Common Venue 8th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West            Liquor Store     Fish & Chips Shop
# Lawrence Park                        Frozen Yogurt Shop     Food & Drink Shop
# Studio District                               Bookstore                   Bar
# The Beaches                              Cosmetics Shop       Coworking Space
# The Danforth West , Riverdale    Furniture / Home Store     Indian Restaurant
#
#                                 9th Most Common Venue  \
# Neighborhood
# India Bazaar , The Beaches West         Burrito Place
# Lawrence Park                             Fish Market
# Studio District                                  Bank
# The Beaches                              Dessert Shop
# The Danforth West , Riverdale           Grocery Store
#
#                                   10th Most Common Venue Postal Code  \
# Neighborhood
# India Bazaar , The Beaches West            Movie Theater         M4L
# Lawrence Park                          Fish & Chips Shop         M4N
# Studio District                              Cheese Shop         M4M
# The Beaches                            Fish & Chips Shop         M4E
# The Danforth West , Riverdale    Fruit & Vegetable Store         M4K
#
#                                          Borough   Latitude  Longitude
# Neighborhood
# India Bazaar , The Beaches West     East Toronto  43.668999 -79.315572
# Lawrence Park                    Central Toronto  43.728020 -79.388790
# Studio District                     East Toronto  43.659526 -79.340923
# The Beaches                         East Toronto  43.676357 -79.293031
# The Danforth West , Riverdale       East Toronto  43.679557 -79.352188

# %%
neighborhoods_venues_sorted = neighborhoods_venues_sorted.reset_index()

# %%
neighborhoods_venues_sorted
# Out:
#                       Neighborhood  Cluster Labels 1st Most Common Venue  \
# 0  India Bazaar , The Beaches West               3  Fast Food Restaurant
# 1                    Lawrence Park               1                  Park
# 2                  Studio District               4                  Café
# 3                      The Beaches               2                 Trail
# 4    The Danforth West , Riverdale               0      Greek Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0        Sandwich Place     Food & Drink Shop                         Pub
# 1           Swim School              Bus Line  Construction & Landscaping
# 2           Coffee Shop               Brewery                   Gastropub
# 3                   Pub     Health Food Store                 Yoga Studio
# 4           Coffee Shop    Italian Restaurant          Frozen Yogurt Shop
#
#      5th Most Common Venue    6th Most Common Venue   7th Most Common Venue  \
# 0       Italian Restaurant                      Gym            Liquor Store
# 1  Comfort Food Restaurant  Fruit & Vegetable Store      Frozen Yogurt Shop
# 2      American Restaurant                   Bakery               Bookstore
# 3                    Diner        Convenience Store          Cosmetics Shop
# 4                Bookstore           Ice Cream Shop  Furniture / Home Store
#
#   8th Most Common Venue 9th Most Common Venue   10th Most Common Venue  \
# 0     Fish & Chips Shop         Burrito Place            Movie Theater
# 1     Food & Drink Shop           Fish Market        Fish & Chips Shop
# 2                   Bar                  Bank              Cheese Shop
# 3       Coworking Space          Dessert Shop        Fish & Chips Shop
# 4     Indian Restaurant         Grocery Store  Fruit & Vegetable Store
#
#   Postal Code          Borough   Latitude  Longitude
# 0         M4L     East Toronto  43.668999 -79.315572
# 1         M4N  Central Toronto  43.728020 -79.388790
# 2         M4M     East Toronto  43.659526 -79.340923
# 3         M4E     East Toronto  43.676357 -79.293031
# 4         M4K     East Toronto  43.679557 -79.352188

# %%
address = 'Toronto, CA'
latitude = None
geolocator = Nominatim(user_agent="ny_explorer")
while (latitude is None):
    try :
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
    except Exception as e:
        latitude =None
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(neighborhoods_venues_sorted['Latitude'], neighborhoods_venues_sorted['Longitude'], neighborhoods_venues_sorted['Neighborhood'], neighborhoods_venues_sorted['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
